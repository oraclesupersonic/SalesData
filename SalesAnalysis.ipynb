# %%
import pandas as pd
import os

# %%
df=pd.read_csv(r'C:\Users\SAIKAT MUKHERJEE\OneDrive\Desktop\PythonAll\DataScience\data\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_April_2019.csv')

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 430.9+ KB

# %%
files=[file for file in os.listdir(r'C:\Users\SAIKAT MUKHERJEE\OneDrive\Desktop\PythonAll\DataScience\data\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]

# %%
files
# Out:
# ['all_months_data.csv',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
all_months_data=pd.DataFrame()  #Blank dataframe
for file in files:
    df=pd.read_csv(r'C:\Users\SAIKAT MUKHERJEE\OneDrive\Desktop\PythonAll\DataScience\data\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\/'+file)
    all_months_data=pd.concat([all_months_data,df])
all_months_data   # all merged data from different csv files

all_months_data.to_csv(r'C:\Users\SAIKAT MUKHERJEE\OneDrive\Desktop\PythonAll\DataScience\data\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\all_months_data.csv',index=False)

# %%
df_new=pd.read_csv(r'C:\Users\SAIKAT MUKHERJEE\OneDrive\Desktop\PythonAll\DataScience\data\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\all_months_data.csv')
df_new
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 934245   259353      AAA Batteries (4-pack)                3       2.99
# 934246   259354                      iPhone                1        700
# 934247   259355                      iPhone                1        700
# 934248   259356      34in Ultrawide Monitor                1     379.99
# 934249   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934250 entries, 0 to 934249
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          931525 non-null  object
#  1   Product           931525 non-null  object
#  2   Quantity Ordered  931525 non-null  object
#  3   Price Each        931525 non-null  object
#  4   Order Date        931525 non-null  object
#  5   Purchase Address  931525 non-null  object
# dtypes: object(6)
# memory usage: 21.4+ MB

# %% [markdown]
# # Clean up data

# %%
df_new.isna().any(axis=1)
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 934245    False
# 934246    False
# 934247    False
# 934248    False
# 934249    False
# Length: 934250, dtype: bool

# %%
df_new[df_new.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 932576      NaN     NaN              NaN        NaN        NaN
# 932838      NaN     NaN              NaN        NaN        NaN
# 933442      NaN     NaN              NaN        NaN        NaN
# 933948      NaN     NaN              NaN        NaN        NaN
# 934226      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 932576              NaN
# ...

# %%
nan_df=df_new[df_new.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
df_new.dropna(how='all',inplace=True)

# %%
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
#https://www.youtube.com/watch?v=eMOA1pPVUc4

# %%
temp_df= df_new[df_new['Order Date'].str[0:2]=='Or']
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 932564  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 932951  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 933963  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 934032  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 934138  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 519     Purchase Address
# 1149    Purchase Address
# 1155    Purchase Address
# 2878    Purchase Address
# ...

# %%
#Remove 'Or'

df_new = df_new[df_new['Order Date'].str[0:2]!='Or']

# %%
new_temp_df=df_new[df_new['Order Date'].str[0:2]=='Or']
new_temp_df
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df_new.loc['Month'] = df_new['Order Date'].str[0:2]
df_new.loc['Month'] = df_new['Month'].astype('int32')
df_new.head()
# Out:
# c:\users\saikat mukherjee\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\saikat mukherjee\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ...

# %% [markdown]
# # DROP NAN rows
